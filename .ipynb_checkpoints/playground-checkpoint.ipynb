# %%
from os import walk, system
import json
import pandas as pd

# %%
schools = json.load(open('out/2022/school_url_pages.json'))

# %%
from helpers.school import SchoolData

# %%
fpath = school_pages['computer_internet']
tables = pd.read_html(fpath)
for tab in tables:
    bool_tab = ('จำนวนคอมพิวเตอร์เพื่อการเรียนการสอน' == tab)
    bool_tab.any().any()
    if bool_tab.any().any():
        df = tab
        break
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_23337/1161104282.py in <module>
# ----> 1 fpath = school_pages['computer_internet']
#       2 tables = pd.read_html(fpath)
#       3 for tab in tables:
#       4     bool_tab = ('จำนวนคอมพิวเตอร์เพื่อการเรียนการสอน' == tab)
#       5     bool_tab.any().any()
#
# NameError: name 'school_pages' is not defined

# %%
tables = pd.read_html(school_pages['computer_internet'])
for table in tables:
  if any('จำนวนคอมพิวเตอร์เพื่อการเรียนการสอน' == table):
    df = table

# %%
df
# Out:
#                                              0  \
# 0  ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง
# 1                                ผู้ให้บริการ:
# 2                                      ประเภท:
# 3                                    ความเร็ว:
# 4                              สถานะการใช้งาน:
# 5                              งบประมาณ/เดือน:
# 6                                ระบบเครือข่าย
# 7                         ระบบเครือข่าย (LAN):
# 8          ระบบเครือข่ายไร้สาย (Wireless LAN):
# 9       ข้อมูล ณ วันที่ 2021-09-03 18:39:38 น.
#
#                                              1
# 0  ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง
# 1                                            -
# 2                                            -
# 3                                            -
# 4                                            -
# 5                                            -
# 6                                ระบบเครือข่าย
# 7                          มีระบบเครือข่าย LAN
# 8         มีระบบเครือข่ายไร้สาย (Wireless LAN)
# 9       ข้อมูล ณ วันที่ 2021-09-03 18:39:38 น.

# %%
pd.read_csv('out/2022-09/school_data/internet.csv')
# Out:
#        Unnamed: 0  Unnamed: 0.1   0             1   2  \
# 0               0           0.0 NaN  ยินดีต้อนรับ NaN
# 1               1           NaN NaN  ยินดีต้อนรับ NaN
# 2               2           NaN NaN  ยินดีต้อนรับ NaN
# 3               3           NaN NaN  ยินดีต้อนรับ NaN
# 4               4           NaN NaN  ยินดีต้อนรับ NaN
# ...           ...           ...  ..           ...  ..
# 29354       29354           NaN NaN           NaN NaN
# 29355       29355           NaN NaN           NaN NaN
# 29356       29356           NaN NaN           NaN NaN
# 29357       29357           NaN NaN           NaN NaN
# 29358       29358           NaN NaN           NaN NaN
#
#                                      3   school_id  0.1           1.1  2.1  \
# 0      หน้าหลักเขตพื้นที่ | admin page  1010720019  NaN           NaN  NaN
# 1      หน้าหลักเขตพื้นที่ | admin page  1010720007  NaN           NaN  NaN
# 2      หน้าหลักเขตพื้นที่ | admin page  1010720023  NaN           NaN  NaN
# 3      หน้าหลักเขตพื้นที่ | admin page  1010720003  NaN           NaN  NaN
# 4      หน้าหลักเขตพื้นที่ | admin page  1010720004  NaN           NaN  NaN
# ...                                ...         ...  ...           ...  ...
# 29354                              NaN  1018090200  NaN  ยินดีต้อนรับ  NaN
# 29355                              NaN  1018090198  NaN  ยินดีต้อนรับ  NaN
# 29356                              NaN  1018090201  NaN  ยินดีต้อนรับ  NaN
# 29357                              NaN  1018090205  NaN  ยินดีต้อนรับ  NaN
# 29358                              NaN  1018090206  NaN  ยินดีต้อนรับ  NaN
#
#                                    3.1
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 29354  หน้าหลักเขตพื้นที่ | admin page
# 29355  หน้าหลักเขตพื้นที่ | admin page
# 29356  หน้าหลักเขตพื้นที่ | admin page
# 29357  หน้าหลักเขตพื้นที่ | admin page
# 29358  หน้าหลักเขตพื้นที่ | admin page
#
# [29359 rows x 11 columns]

# %% [markdown]
# # Computer and internet

# %%
import pandas as pd

# %%
dfs = pd.read_html('out/2022/html/school/computer_internet/1010720040.html')

def _df_to_dict(df):
    header = ''
    rows = dict()
    df
    for i, row in df.iterrows():
        if len(row.unique()) != len(row):
            header = row[0]
        else:
            row_list = row.values.tolist()
            col, cell = row_list
            if col not in rows.keys():
                rows[col] = dict()
            rows[col][header] = cell
    return rows
rows = _df_to_dict(dfs[5])
pd.DataFrame(rows)
# Out:
#                                   index งบประมาณ สพฐ. จัดหาเอง/บริจาค:  \
# 0   จำนวนคอมพิวเตอร์เพื่อการเรียนการสอน   245 เครื่อง      111 เครื่อง
# 1  จำนวนคอมพิวเตอร์เพื่อการบริหารจัดการ     0 เครื่อง        0 เครื่อง
# 2                จำนวนคอมพิวเตอรทั้งหมด           NaN              NaN
#
#            รวม   ใช้งานได้: ใช้งานไม่ได้: คอมพิวเตอร์:
# 0  356 เครื่อง  356 เครื่อง     0 เครื่อง          NaN
# 1    0 เครื่อง    0 เครื่อง     0 เครื่อง          NaN
# 2          NaN  356 เครื่อง     0 เครื่อง  356 เครื่อง

# %%
def _internet_helper(df):
    header = ''
    rows = dict()
    for i, row in df.iterrows():
        if len(row.unique()) != len(row):
            header = row[0]
        else:
            row_list = row.values.tolist()
            col, cell = row_list
            rows[header+'_'+col] = cell
    df = pd.DataFrame([rows.values()], columns=rows.keys())
    return df
# Out:
#   ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง.ผู้ให้บริการ:  \
# 0                                                3BB
#
#   ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง.ประเภท:  \
# 0                                        fiber optic
#
#   ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง.ความเร็ว:  \
# 0                                       100/100 Mbps
#
#   ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง.สถานะการใช้งาน:  \
# 0                                            OK Mbps
#
#   ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง.งบประมาณ/เดือน:  \
# 0                                               5000
#
#   ระบบเครือข่าย.ระบบเครือข่าย (LAN):  \
# 0                มีระบบเครือข่าย LAN
#
#   ระบบเครือข่าย.ระบบเครือข่ายไร้สาย (Wireless LAN):
# 0              มีระบบเครือข่ายไร้สาย (Wireless LAN)

# %% [markdown]
# # Durable Goods

# %%
from src.indexer import Index

# %%
index = Index('out/2022/result_index.txt')

# %%
def read_first_line(fpath):
  with open(fpath, 'r') as file:
    line = ''
    c = ''
    while c != '\n':
      c = file.read(1)
      line += c
    return line

# %%
# %time
read_first_line('out/2022/url_index.txt')
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 16 µs
# 'https://bobec.bopp-obec.info/build_sch_list.php?Area_CODE=100001\tout/2022/html/area/100001.html\n'

# %%
durable_goods = [x for x in index.index.keys() if x.split('.')[1] == 'durable_goods']
headers = {x: read_first_line(index[x]) for x in durable_goods}

# %%
def uniq(items):
  unique_items = []
  for i in items:
    if i not in unique_items:
      unique_items.append(i)
  return unique_items

uniq(headers.values())
# Out:
# ['ลำดับ,รหัส,รายการ,รายการ(cm.),จำนวนที่ใช้ได้,จำนวนรอซ่อม,จำนวนรอจำหน่าย\n']

# %%
target = '<!-- .style37 {color: #FFFFFF; font-family: Tahoma; } .style40 {font-family: Tahoma; font-size: 12px; } -->  เมนูหลัก  หน้าหลักเขตพื้นที่  ข้อมูลพื้นฐานโรงเรียน  ข้อมูลนักเรียน  ข้อมูลครูบุคลากร  ข้อมูลคอมพิวเตอร์ อินเทอร์เน็ต  ข้อมูลสิ่งก่อสร้าง  ข้อมูลครุภัณฑ์  เขตพื้นที่บริการ  ข่าวประชาสัมพันธ์,ข้อมูลครุภัณฑ์ (M-OBEC) โรงเรียนราชสีมาวิทยาลัย\n'

for k, x in headers.items():
  if x == target:
    break

# %%
index[k]
# Out:
# 'out/2022/school_data/school/1030201355/durable_goods.csv'

# %% [markdown]
# # Rename header

# %%
filepaths = [
  'out/2022/school_data/building.csv',
  'out/2022/school_data/computer.csv',
  'out/2022/school_data/durable_goods.csv',
  'out/2022/school_data/general.csv',
  'out/2022/school_data/internet.csv',
  'out/2022/school_data/staff.csv',
  'out/2022/school_data/student.csv'
]

# %%
# headers = [read_first_line(fp) for fp in filepaths]

# %%
with open('header_map.json') as fp:
  mapper = json.load(fp)

# %%
dir = 'building'
df = pd.read_csv(f'out/2022/school_data/{dir}.csv', index_col=0)

# %%
dir_mapper = mapper[dir]
dir_mapper = {old: new for old, new in dir_mapper.items() if new}
df[['school_id'] + [col for col in df.columns if col != 'school_id']]\
  .rename(dir_mapper, axis=1)\
  .fillna('-')
# Out:
#          school_id                                               name  \
# 0       1010720019                             อาคารเรียน ลำดับที่ 1
# 1       1010720019                             อาคารเรียน ลำดับที่ 2
# 2       1010720019                          บ้านพักภารโรง ลำดับที่ 1
# 3       1010720007                             อาคารเรียน ลำดับที่ 1
# 4       1010720007                             อาคารเรียน ลำดับที่ 2
# ...            ...                                                ...
# 402708  1018090206  อาคารอเนกประสงค์/โรงอาหาร/โรงฝึกงาน/หอประชุม ล...
# 402709  1018090206                             บ้านพักครู ลำดับที่ 1
# 402710  1018090206                             บ้านพักครู ลำดับที่ 2
# 402711  1018090206                                   ส้วม ลำดับที่ 1
# 402712  1018090206                               สนามกีฬา ลำดับที่ 1
#
#                                                 model room_number   build_at  \
# 0                                                 004     18 ห้อง  พ.ศ. 2497
# 1               108 ล,108 ,ล/30,108 หรือ108 ชื่ออื่นๆ     15 ห้อง  พ.ศ. 2528
# 2                                           อื่น อื่น           -  พ.ศ. 2538
# 3       อื่นๆ 004,008,030,107,206,210,214,315,415,308     24 ห้อง  พ.ศ. 2516
# 4       อื่นๆ 004,008,030,107,206,210,214,315,415,308     24 ห้อง  พ.ศ. 2529
# ...                                               ...         ...        ...
# 402708                                     สปช.202/26           -  พ.ศ. 2530
# 402709                                       กรมสามัญ           -  พ.ศ. 2516
# 402710                              บ้านพักครู 203/27           -  พ.ศ. 2561
# 402711                   อาคาร สพฐ. 4(ส้วม 4 ที่นั่ง)           -  พ.ศ. 2560
# 402712                                     สนามฟุตซอล           -  พ.ศ. 2558
#
#        current_condition                                        image_url_0  \
# 0                     ดี  https://bobec.bopp-obec.info/b01/7200191012124...
# 1                     ดี  https://bobec.bopp-obec.info/b01/7200192012125...
# 2                     ดี  https://bobec.bopp-obec.info/b04/7200191040225...
# 3                  พอใช้  https://bobec.bopp-obec.info/b01/7200071012125...
# 4                  พอใช้  https://bobec.bopp-obec.info/b01/7200072012125...
# ...                  ...                                                ...
# 402708                ดี  https://bobec.bopp-obec.info/b02/9020610202253...
# 402709             พอใช้  https://bobec.bopp-obec.info/b03/9020610304251...
# 402710                ดี  https://bobec.bopp-obec.info/b03/1801020520309...
# 402711             พอใช้  https://bobec.bopp-obec.info/b05/1801020560514...
# 402712             พอใช้  https://bobec.bopp-obec.info/b15/9020611512255...
#
#                                               image_url_1
# 0       https://bobec.bopp-obec.info/b01/7200191012124...
# 1       https://bobec.bopp-obec.info/b01/7200192012125...
# 2       https://bobec.bopp-obec.info/b04/7200191040225...
# 3       https://bobec.bopp-obec.info/b01/7200071012125...
# 4       https://bobec.bopp-obec.info/b01/7200072012125...
# ...                                                   ...
# 402708  https://bobec.bopp-obec.info/b02/9020610202253...
# 402709  https://bobec.bopp-obec.info/b03/9020610304251...
# 402710  https://bobec.bopp-obec.info/b03/1801020520309...
# 402711  https://bobec.bopp-obec.info/b05/1801020560514...
# 402712  https://bobec.bopp-obec.info/b15/9020611512255...
#
# [402713 rows x 8 columns]

# %%
# Out:
# ['school_id',
#  'name',
#  'แบบ',
#  'จำนวนห้องตามแปลน',
#  'สร้าง',
#  'สภาพปัจจุบัน',
#  'image_url_0',
#  'image_url_1']

# %%
map[dir]
# Out:
# {'school_id': '',
#  'name': '',
#  'แบบ': 'model',
#  'จำนวนห้องตามแปลน': 'room_number',
#  'สร้าง': 'build_at',
#  'สภาพปัจจุบัน': 'current_condition',
#  'image_url_0': '',
#  'image_url_1': ''}

# %%
# JSON Format

# %%
import helpers.school as sh
from helpers.utils import *
import re

# %%
school_ids = list(schools.keys())

# %%
schools_pages_fpath = os.path.join(ROOT_DIR, 'school_file_path_pages.json')
schools_pages = load_json(schools_pages_fpath)

# %%
class SchoolData:
    def __init__(self, school_id: str, page_fpaths: Dict) -> None:
        self.school_id = school_id
        self.pages: Dict = page_fpaths
        self.save_dir = os.path.join(
            ROOT_DIR, 'school_data', 'school', school_id)

    def general(self) -> Dict:
        about_school: Dict = dict()
        about_school_json: List = dict()
        soup: BeautifulSoup = load_soup(self.pages['general'])
        table = soup.find('table').find('table', attrs={'width': '521'})
        for comment in soup.children:
            break
        url: str = re.findall('url: (.*)\n', comment)[0]

        parent_url: str = re.sub('[^/]*$', '', url)

        for table_row in table.find_all('tr'):
            cells = table_row.find_all('td')

            if len(cells) == 2:
                key_name: str = clean_text(cells[0].text)
                value: str = clean_text(cells[1].text)
                
                if cells[1].find_all('a'):
                    _id = 0
                    links = []
                    for a_tag in cells[1].find_all('a'):
                        if not a_tag.text: continue
                        links.append({
                            "text": a_tag.text,
                            "url": (parent_url
                                if not a_tag.attrs['href'].startswith('http')
                                else '') + a_tag.attrs['href']
                        })
                    about_school_json.update({"links": links})
                    continue

                about_school_json[key_name] = value

        image_dir: str = SCRAPED_FILE_DIRS['general']+'/image'

        if not is_path_existed(image_dir):
            makedirs(image_dir)

        for div in soup.find_all('div'):
            if not div.find('div'):
                temp = {}
                if 'ผู้อำนวยการโรงเรียน' in div.text:
                    image = div.find('img')
                    about_school_json['principal'] = {
                        'name': div.text.strip().split('\n')[0],
                        'position_title': div.text.strip().split('\n')[1].strip()
                    }
                    image = div.find('img')
                    if image is not None:
                        image_src = image.attrs['src']
                        about_school_json['principal']['image_path'] = parent_url + image_src
                    
                elif 'ตราสัญลักษณ์' in div.text:
                    dir_name = 'logo'
                    image = div.find('img')
                    if image is not None:
                        image_src = image.attrs['src']
                        about_school_json['logo_image_path'] = parent_url + image_src
        
        about_school_json['latlng'] = None
        js_text: str = ' '.join(
            [script.text for script in soup.find_all('script')])
        latlng: str = re.findall('LatLng\((.*)\)', js_text)
        if latlng and ',' in latlng[0]:
            about_school_json['latlng'] = latlng[0].split(',')

        df = pd.DataFrame(about_school)
        
        return about_school_json

    def student(self) -> Dict:
        df: pd.DataFrame = self._find_html_table('student', 'ชั้น/เพศ')
        if df is not None:
            col_headers = df.iloc[0]
            df.columns = col_headers
            if len(df) > 2:
                df = df.iloc[1:-1]
        df.replace('-', None, inplace=True)
        return dict(zip(student_df.iloc[:,0].tolist(), student_df.iloc[:,1:].to_dict('records')))
    
    def staff(self) -> Dict:
        staff_df: pd.DataFrame = self._find_html_table('staff', 'วิทยฐานะ')
        if staff_df is not None:
            staff_data = {}
            for g, group_df in staff_df.iloc[2:].groupby(0):
                g = re.sub('\d\. ?','',g)
                values = [dict(zip(staff_df.iloc[1, 3:].values, row))
                    for row
                    in group_df.iloc[:, 3:].values]

                staff_data[g] = [{**({staff_df.iloc[0, 1]: group_df.iloc[i, 1]} if group_df.iloc[i, 1] != '-' else {}),
                                **({staff_df.iloc[0, 2]: group_df.iloc[i, 2]} if group_df.iloc[i, 2] != '-' else {}),
                                staff_df.iloc[0, 3]: row}
                                for i, row
                                in enumerate(values) if group_df.iloc[i, 1] != 'รวม']
            return staff_data

    def _find_html_table(self, page, keyword):
        fpath = self.pages[page]
        tables = pd.read_html(fpath)
        for table in tables:
            table_bool = (keyword == table)
            if table_bool.any().any():
                df = table
                return df
            
    def internet(self) -> Dict:
        df = self._find_html_table(
            'computer_internet', 'ระบบเครือข่ายอินเทอร์เน็ตที่โรงเรียนเช่าเอง')
        if df is None: {}
        header = ''
        rows = dict()
        for i, row in df.iterrows():
            if len(row.unique()) != len(row):
                header = row[0]
            else:
                row_list = row.values.tolist()
                col, cell = row_list
                if header not in rows.keys(): rows[header] = dict()
                rows[header][col] = cell if cell != '-' else None
        return rows
    
    def durable_goods(self) -> Dict:
        df = self._find_html_table('durable_goods', 'จำนวนรอจำหน่าย')
        if df is not None:
            df.columns = df.iloc[0]
            df = df.iloc[1:, :]
            df = df.iloc[:-1]
        return df

# %%
school_index = 101
school_data = SchoolData(school_ids[school_index], schools_pages[school_ids[school_index]])

# %%
df = school_data.durable_goods()
df.to_dict('records')
# Out:
# [{'ลำดับ': '1',
#   'รหัส': '11001',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โต๊ะเก้าอี้นักเรียนก่อนประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '2',
#   'รหัส': '11002',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ชุดฝึกทักษะนักเรียนก่อนประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '3',
#   'รหัส': '11003',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ตู้เก็บอุปกรณ์นักเรียนก่อนประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '4',
#   'รหัส': '21001',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องถ่ายเอกสาร',
#   'จำนวนที่ใช้ได้': '11',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '5',
#   'รหัส': '21002',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องพิมพ์สำเนาระบบดิจิตอล',
#   'จำนวนที่ใช้ได้': '2',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '6',
#   'รหัส': '21003',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องโทรสาร',
#   'จำนวนที่ใช้ได้': '6',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '7',
#   'รหัส': '21004',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องอัดสำเนา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '8',
#   'รหัส': '21005',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องพิมพ์ดีด',
#   'จำนวนที่ใช้ได้': '5',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '9',
#   'รหัส': '21006',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'ตู้นิรภัย',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '10',
#   'รหัส': '21007',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องไมโครคอมพิวเตอร์',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '11',
#   'รหัส': '21008',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องพิมพ์ (Printer)',
#   'จำนวนที่ใช้ได้': '60',
#   'จำนวนรอซ่อม': '8',
#   'จำนวนรอจำหน่าย': '5'},
#  {'ลำดับ': '12',
#   'รหัส': '21009',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องเจาะกระดาษและเข้าเล่ม',
#   'จำนวนที่ใช้ได้': '8',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '13',
#   'รหัส': '21010',
#   'รายการ': 'ครุภัณฑ์สำนักงาน โรงเรียน',
#   'รายการ(cm.)': 'เครื่องถ่ายภาพนิ่งระบบดิจิตอล',
#   'จำนวนที่ใช้ได้': '6',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '14',
#   'รหัส': '21011',
#   'รายการ': 'ครุภัณฑ์สำนักงาน/โรงเรียน',
#   'รายการ(cm.)': 'คอมพิวเตอร์พกพา(Tablet)(ใช้บริหารจัดการ)',
#   'จำนวนที่ใช้ได้': '350',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '15',
#   'รหัส': '21012',
#   'รายการ': 'ครุภัณฑ์สำนักงาน/โรงเรียน',
#   'รายการ(cm.)': 'เครื่องคอมพิวเตอร์พกพา(Notebook)(ใช้บริหารจัดการ)',
#   'จำนวนที่ใช้ได้': '30',
#   'จำนวนรอซ่อม': '5',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '16',
#   'รหัส': '21013',
#   'รายการ': 'ครุภัณฑ์สำนักงาน/โรงเรียน',
#   'รายการ(cm.)': 'กล้องถ่ายภาพดิจิตอล',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '1',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '17',
#   'รหัส': '22001',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โต๊ะเก้าอี้นักเรียน ประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '18',
#   'รหัส': '22002',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โต๊ะเก้าอี้นักเรียน มัธยมศึกษา',
#   'จำนวนที่ใช้ได้': '2830',
#   'จำนวนรอซ่อม': '25',
#   'จำนวนรอจำหน่าย': '9'},
#  {'ลำดับ': '19',
#   'รหัส': '22003',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์การสอนวิทยาศาสตร์ ประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '20',
#   'รหัส': '22004',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์อุปกรณ์วิทยาศาสตร์ ม.ต้น',
#   'จำนวนที่ใช้ได้': '4',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '21',
#   'รหัส': '22005',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์วิทยาศาสตร์ ม.ปลาย',
#   'จำนวนที่ใช้ได้': '5',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '22',
#   'รหัส': '22006',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'หุ่นจำลองแสดงอวัยวะภายในมนุษย์',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '23',
#   'รหัส': '22007',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์ไฟฟ้า',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '24',
#   'รหัส': '22008',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานอาหารและโภชนาการ',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '25',
#   'รหัส': '22009',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานผ้าและการตัดเย็บ',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '26',
#   'รหัส': '22010',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์โรงฝึกงาน',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '27',
#   'รหัส': '22011',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานไม้',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '28',
#   'รหัส': '22012',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานโลหะ',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '29',
#   'รหัส': '22013',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์ชางอุตสาหกรรม',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '30',
#   'รหัส': '22014',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานยนต์',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '31',
#   'รหัส': '22015',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์วิชาคหกรรม',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '32',
#   'รหัส': '22016',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์วิชาศิลปกรรม',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '33',
#   'รหัส': '22017',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์ห้องปฏิบัติการเพาะเห็ด',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '34',
#   'รหัส': '22018',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ฃุดอุปกรณ์วิชาชีพเกษตรกรรม',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '35',
#   'รหัส': '22019',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์งานเขียนแบบ ม.ต้น',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '36',
#   'รหัส': '22020',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องดนตรีสากล',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '37',
#   'รหัส': '22021',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องดนตรีไทย ชุดเล็ก ประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '38',
#   'รหัส': '22022',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องดนตรีไทย ชุดใหญ่ มัธยมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '39',
#   'รหัส': '22023',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ชุดอุปกรณ์วิชาพลานามัย',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '40',
#   'รหัส': '22024',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โต๊ะเทเบิลเทนนิส',
#   'จำนวนที่ใช้ได้': '2',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '41',
#   'รหัส': '22025',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ชุดอุปกรณ์เปตอง',
#   'จำนวนที่ใช้ได้': '2',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '42',
#   'รหัส': '22026',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โทรทัศน์สี',
#   'จำนวนที่ใช้ได้': '21',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '43',
#   'รหัส': '22027',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'วิทยุ - เทป - ซีดี',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '44',
#   'รหัส': '22028',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องเล่น ดีวีดี',
#   'จำนวนที่ใช้ได้': '4',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '45',
#   'รหัส': '22029',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'จานรับสัญญาณดาวเทียม',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '46',
#   'รหัส': '22030',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์ห้องสมุด ชุดเล็ก ประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '47',
#   'รหัส': '22031',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์ห้องสมุด ชุดใหญ่ มัธยมศึกษา',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '48',
#   'รหัส': '22032',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องมัลติมีเดียโปรเจคเตอร์ LCD',
#   'จำนวนที่ใช้ได้': '12',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '49',
#   'รหัส': '22033',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องไมโครคอมพิวเตอร์',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '50',
#   'รหัส': '22034',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องพิมพ์ (Printer)',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '51',
#   'รหัส': '22035',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'อุปกรณ์ห้องสมุดรร.ระดับประถมศึกษา-มัธยมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '52',
#   'รหัส': '22036',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์พัฒนาทักษะคิดวิเคราะห์ระดับก่อนประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '53',
#   'รหัส': '22037',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'ครุภัณฑ์พัฒนาทักษะคิดวิเคราะห์ระดับประถมศึกษา',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '54',
#   'รหัส': '22038',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'อุปกรณ์ศูนย์การเรียนรร.ขนาดเล็ก',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '55',
#   'รหัส': '22039',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'อุปกรณ์ห้องปฏิบัติการวิทยาศาสตร์ (ประถม-มัธยมต้น)',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '56',
#   'รหัส': '22040',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'อุปกรณ์ห้องปฏิบัติการวิทยาศาสตร์ (มัธยมศึกษา)',
#   'จำนวนที่ใช้ได้': '9',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '57',
#   'รหัส': '22041',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'คอมพิวเตอร์พกพา(Tablet)',
#   'จำนวนที่ใช้ได้': '22',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '58',
#   'รหัส': '22042',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'เครื่องคอมพิวเตอร์พกพา(Notebook)(ใช้ในการเรียนการสอน)',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '59',
#   'รหัส': '22043',
#   'รายการ': 'ครุภัณฑ์การศึกษา',
#   'รายการ(cm.)': 'โทรทัศน์สีชนิด จอแบน (LCD)',
#   'จำนวนที่ใช้ได้': '4',
#   'จำนวนรอซ่อม': '1',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '60',
#   'รหัส': '23001',
#   'รายการ': 'ครุภัณฑ์ไฟฟ้าและวิทยุ',
#   'รายการ(cm.)': 'เครื่องกำเนิดไฟฟ้าพลังแสงอาทิตย์ เบนซิน',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '61',
#   'รหัส': '23002',
#   'รายการ': 'ครุภัณฑ์ไฟฟ้าและวิทยุ',
#   'รายการ(cm.)': 'เครื่องตัดกระแสไฟฟ้า',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '62',
#   'รหัส': '23003',
#   'รายการ': 'ครุภัณฑ์ไฟฟ้าและวิทยุ',
#   'รายการ(cm.)': 'เครื่องขยายเสียง',
#   'จำนวนที่ใช้ได้': '10',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '63',
#   'รหัส': '23004',
#   'รายการ': 'ครุภัณฑ์ไฟฟ้าและวิทยุ',
#   'รายการ(cm.)': 'เครื่องกำเนิดไฟฟ้า 5, 10 กิโลวัตต์',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '64',
#   'รหัส': '23005',
#   'รายการ': 'ครุภัณฑ์ไฟฟ้าและวิทยุ',
#   'รายการ(cm.)': 'เครื่องปรับอากาศ',
#   'จำนวนที่ใช้ได้': '58',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '65',
#   'รหัส': '24001',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'เครื่องกรองน้ำ',
#   'จำนวนที่ใช้ได้': '6',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '66',
#   'รหัส': '24002',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'เครื่องทำน้ำเย็น',
#   'จำนวนที่ใช้ได้': '10',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '67',
#   'รหัส': '24003',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ถังน้ำขนาด 2000 ลิตร แบบไฟเบอร์กลาส',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '68',
#   'รหัส': '24004',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'เครื่องตัดหญ้า',
#   'จำนวนที่ใช้ได้': '4',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '69',
#   'รหัส': '24005',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'โต๊ะอาหารพร้อมเก้าอี้',
#   'จำนวนที่ใช้ได้': '179',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '70',
#   'รหัส': '24006',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ตู้เย็น',
#   'จำนวนที่ใช้ได้': '11',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '71',
#   'รหัส': '24007',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ถังน้ำขนาด 2000 ลิดร แบบพลาสติก',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '72',
#   'รหัส': '24008',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ถังน้ำขนาด 1000 ลิตร ขึ้นไป แบบไฟเบอร์กลาส',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '73',
#   'รหัส': '24009',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ถังน้ำขนาด 1000 ลิตร ขึ้นไป แบบพลาสติก',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '74',
#   'รหัส': '24010',
#   'รายการ': 'ครุภัณฑ์งานบ้านและงานครัว',
#   'รายการ(cm.)': 'ถังน้ำขนาด 1000 ลิตร ขึ้นไป แบบสแตนเลส',
#   'จำนวนที่ใช้ได้': '0',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '75',
#   'รหัส': '25001',
#   'รายการ': 'ครุภัณฑ์ยานพาหนะ',
#   'รายการ(cm.)': 'รถโดยสาร 12 ที่นั่ง',
#   'จำนวนที่ใช้ได้': '3',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '0'},
#  {'ลำดับ': '76',
#   'รหัส': '25002',
#   'รายการ': 'ครุภัณฑ์ยานพาหนะ',
#   'รายการ(cm.)': 'รถกระบะ',
#   'จำนวนที่ใช้ได้': '1',
#   'จำนวนรอซ่อม': '0',
#   'จำนวนรอจำหน่าย': '1'}]

# %%
import re
staff_data = {}
for g, group_df in df.iloc[2:].groupby(0):
    g = re.sub('\d\. ?','',g)
    values = [dict(zip(df.iloc[1, 3:].values, row))
           for row
           in group_df.iloc[:, 3:].values]

    staff_data[g] = [{**({df.iloc[0,1]: group_df.iloc[i, 1]} if group_df.iloc[i, 1] != '-' else {}),
                      **({df.iloc[0,2]: group_df.iloc[i, 2]} if group_df.iloc[i, 2] != '-' else {}),
                      df.iloc[0,3]: row}
                     for i, row
                     in enumerate(values) if group_df.iloc[i, 1] != 'รวม']

# %%
staff_data
# Out:
# {'ผู้อำนวยการโรงเรียน': [{'ระดับ': 'คศ.1',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'ชำนาญการ',
#    'ระดับ': 'คศ.2',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'ชำนาญการพิเศษ',
#    'ระดับ': 'คศ.3',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '1',
#     'หญิง': '0',
#     'รวม': '1'}},
#   {'วิทยฐานะ': 'เชี่ยวชาญ',
#    'ระดับ': 'คศ.4',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'เชี่ยวชาญพิเศษ',
#    'ระดับ': 'คศ.5',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'รองผู้อำนวยการโรงเรียน': [{'ระดับ': 'คศ.1',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'ชำนาญการ',
#    'ระดับ': 'คศ.2',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'ชำนาญการพิเศษ',
#    'ระดับ': 'คศ.3',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}},
#   {'วิทยฐานะ': 'เชี่ยวชาญ',
#    'ระดับ': 'คศ.4',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'ครู': [{'ระดับ': 'คศ.1',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '20',
#     'หญิง': '34',
#     'รวม': '54'}},
#   {'วิทยฐานะ': 'ชำนาญการ',
#    'ระดับ': 'คศ.2',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '12',
#     'หญิง': '22',
#     'รวม': '34'}},
#   {'วิทยฐานะ': 'ชำนาญการพิเศษ',
#    'ระดับ': 'คศ.3',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '2',
#     'หญิง': '12',
#     'รวม': '14'}},
#   {'วิทยฐานะ': 'เชี่ยวชาญ',
#    'ระดับ': 'คศ.4',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '1',
#     'หญิง': '0',
#     'รวม': '1'}},
#   {'วิทยฐานะ': 'เชี่ยวชาญพิเศษ',
#    'ระดับ': 'คศ.5',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'ครูผู้ช่วย': [{'ระดับ': 'ครูผู้ช่วย',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '9',
#     'หญิง': '19',
#     'รวม': '28'}}],
#  'ลูกจ้างประจำ': [{'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'พนักงานราชการ': [{'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'ลูกจ้างชั่วคราว': [{'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '0',
#     'หญิง': '0',
#     'รวม': '0'}}],
#  'รวมทั้งหมด': [{'วิทยฐานะ': 'รวมทั้งหมด',
#    'ระดับ': 'รวมทั้งหมด',
#    'ข้าราชการครูและบุคลากรทางการศึกษา (คน)': {'ชาย': '45',
#     'หญิง': '87',
#     'รวม': '132'}}]}
